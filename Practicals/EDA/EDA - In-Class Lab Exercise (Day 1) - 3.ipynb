# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
# type your code here
data=pd.read_csv('adult.csv')
data
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital.gain      32561 non-null int64
# capital.loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data_num=data.select_dtypes(include=np.number)
data_cat=data.select_dtypes(exclude=np.number)

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data['hours.per.week'].corr(data['age'])
# Out:
# 0.06875570750955737

# %%
sns.scatterplot(data['hours.per.week'],data['age'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-YES Effect of a person's age on the working hours is More Between 25 to 60

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
#numeric vs categorical
data.groupby('education')['capital.gain'].mean().plot(kind='line')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### INFERENCE:-The trend of the capital gain amount for different educational qualifications ARE More in Masters,Doctorate,Prof-School

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(data['hours.per.week'],data['capital.gain'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-the effect of working hours of individuals on capital gain is more between age of 25 to 60

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(data['hours.per.week'],data['age'])
plt.show()

# %%
#the trend in the average working hours corresponding to the age of an individual
data.groupby('age')['hours.per.week'].mean().plot(kind='line')
plt.show()

# %% [markdown]
# ##### INFERENCE:-hours.per.week INCREASES WRT AGE  UPTO RANGE OF 60 AND THEN DECREASES.AND THEN FLUCTUATES FROM AGE OF 60-100

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data.groupby('age')['capital.loss'].mean().plot(kind='kde')
plt.show()

# %% [markdown]
# ##### INFERENCE:- the distribution of the average capital loss corresponding to the age is normal between -100 to 100 and also same between 300 to 500

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data['age'].corr(data['capital.gain'])
# Out:
# 0.0776744981659936

# %%
sns.scatterplot(data['capital.gain'],data['age'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-NO negative relation between capital gain and age

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data.groupby('income')['age'].mean()
# Out:
# income
# <=50K    36.783738
# >50K     44.249841
# Name: age, dtype: float64

# %% [markdown]
# ##### INFERENCE:-IN >50k INCOME AVERAGE/MEAN AGE IS MORE THAN <=50K INCOME LEVEL.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.violinplot(data['sex'],data['hours.per.week'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-MALE hours.per.week IS WORK MORE THAN FEMALE

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here category vs category
tab=pd.crosstab(data['income'],data['education'])
tab
#grouped bar
tab.plot(kind='bar')#GROUPEDBAR
plt.show()

# %% [markdown]
# ##### INFERENCE:-IN BOTH >50K AND <=50K HS-GRAD PEOPLE EARN MORE THAN OTHERS

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data.groupby('sex')['age'].mean()
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %% [markdown]
# ##### INFERENCE:-the average age of males ARE 39.4 and females ARE 36.86.MALE HAVE AVERAGE AGE COMPARED TO FEMALE

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.violinplot(data['income'],data['hours.per.week'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-IN <=50K HAVE LESS hours.per.week THAN >50K.WERE >50K MORE hours.per.week

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
#1-numeric age and 2 categorical-gender and race of the individual
sns.violinplot(x=data['sex'],y=data['age'],hue=data['race'])#in hue always categorical
plt.show()

# %%
data.groupby('sex')['age','race'].skew()
# Out:
#              age
# sex
# Female  0.678912
# Male    0.519841

# %% [markdown]
# ##### INFERENCE:- BOTH GENDER HAVE positively skewed distributions based on the gender and race of the individual

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(data['hours.per.week'],data['workclass'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-FEDERAL GOVT EMPLOYEES HAVE MORE LESS  NO.OF WORKING hours.per.week COMPARED TO OTHER WORKING CLASS

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
data.groupby('sex')['fnlwgt'].mean()
# Out:
# sex
# Female    185746.311206
# Male      191771.449013
# Name: fnlwgt, dtype: float64

# %%
sns.boxplot(data['sex'],data['fnlwgt'])
plt.show()

# %% [markdown]
# ##### INFERENCE:-MALE AND FEMALE HAVE SAME demographic characteristics

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
tab_ig=pd.crosstab(data['sex'],data['income'])/data['income'].value_counts()
tab_ig
# Out:
# income     <=50K      >50K
# sex
# Female  0.388026  0.150363
# Male    0.611974  0.849637

# %%
tab_ig.plot(kind='bar')#GROUPEDBAR
plt.show()

# %%
tab_ig.plot(kind='bar',stacked=True)#GROUPEDBAR
plt.show()

# %% [markdown]
# ##### INFERENCE:-MALE INCOME ARE MORE BIASED THAN FEMALE IN BOTH <=50K AND >50K

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
tab_ir=pd.crosstab(data['income'],data['race'])
tab_ir
# Out:
# race    Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White
# income
# <=50K                  275                 763   2737    246  20699
# >50K                    36                 276    387     25   7117

# %%
tab_ir.plot(kind='bar')
plt.show()

# %% [markdown]
# ##### INFERENCE:-IN <=50K AND >50K WHITE RACE EARN MORE THAN OTHERS.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
tab_m=pd.crosstab(data['sex'],data['occupation'])
tab_m
# Out:
# occupation     ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# sex
# Female       841          2537             0           222             1159
# Male        1002          1233             9          3877             2907
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# sex
# Female                   65                164                550
# Male                    929               1206               1452
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# sex
# Female               1800              141            1515               76
# Male                 1495                8            2625              573
#
# occupation  Sales  Tech-support  Transport-moving
# sex
# Female       1263           348                90
# Male         2387           580              1507

# %%
tab_m.plot(kind='bar')
plt.show()

# %% [markdown]
# ##### INFERENCE:-Female WORK MORE IN Adm-clerical.MALE DOMINATE IN Craft-repair

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
tab_iw=pd.crosstab(data['income'],data['workclass'])
tab_iw
# Out:
# workclass     ?  Federal-gov  Local-gov  Never-worked  Private  Self-emp-inc  \
# income
# <=50K      1645          589       1476             7    17733           494
# >50K        191          371        617             0     4963           622
#
# workclass  Self-emp-not-inc  State-gov  Without-pay
# income
# <=50K                  1817        945           14
# >50K                    724        353            0

# %%
tab_iw.plot(kind='bar')
plt.show()

# %% [markdown]
# ##### INFERENCE:-working class IN BOTH<=50K AND >50K PRIVATE working class HAVE MORE NO.OF INCOME.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
tab_im=pd.crosstab(data['income'],data['marital.status'])
tab_im
# Out:
# marital.status  Divorced  Married-AF-spouse  Married-civ-spouse  \
# income
# <=50K               3980                 13                8284
# >50K                 463                 10                6692
#
# marital.status  Married-spouse-absent  Never-married  Separated  Widowed
# income
# <=50K                             384          10192        959      908
# >50K                               34            491         66       85

# %%
tab_im.plot(kind='bar')
plt.show()

# %% [markdown]
# ##### OBSERVATION:-IN <=50K Never-married HAVE MORE INCOME.IN >50K Married-civ-spouse HAVE MORE INCOME

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
tab_ic=pd.crosstab(data['income'],data['occupation'])
tab_ic
# Out:
# occupation     ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# income
# <=50K       1652          3263             8          3170             2098
# >50K         191           507             1           929             1968
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# income
# <=50K                   879               1284               1752
# >50K                    115                 86                250
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# income
# <=50K                3158              148            2281              438
# >50K                  137                1            1859              211
#
# occupation  Sales  Tech-support  Transport-moving
# income
# <=50K        2667           645              1277
# >50K          983           283               320

# %%
tab_ic.plot(kind='bar')
plt.show()

# %% [markdown]
# ##### INFERENCE:- IN <=50K OCCUPATION Adm-clerical HAVE MORE INCOME.IN >50K Exec-managerial HAVE MORE INCOME
